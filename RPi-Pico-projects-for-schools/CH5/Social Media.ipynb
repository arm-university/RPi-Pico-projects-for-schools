# %%
import pandas as pd

# %%
data= pd.read_csv("socialmedia.csv")
data
# Out:
#     period  YouTube  Facebook  Pinterest  time_spent
# 0        1     True     False      False          14
# 1        2    False     False       True           0
# 2        3    False      True       True           3
# 3        4     True      True       True           4
# 4        5    False     False      False           2
# 5        6     True     False      False           2
# 6        7     True     False       True           8
# 7        8     True     False       True          15
# 8        9     True      True      False           1
# 9       10     True     False       True          12
# 10      11     True      True      False           9
# 11      12     True     False       True           9
# 12      13    False     False       True          13
# 13      14    False      True      False          12
# 14      15    False      True      False           1
# 15      16    False     False       True           7
# 16      17     True      True      False           8
# ...

# %%
data.describe()
# Out:
#           period  time_spent
# count  36.000000   36.000000
# mean   18.500000    7.388889
# std    10.535654    4.883077
# min     1.000000    0.000000
# 25%     9.750000    2.000000
# 50%    18.500000    7.500000
# 75%    27.250000   12.000000
# max    36.000000   15.000000

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
plt.xlabel("Period")
plt.ylabel("Time Spent")
data['time_spent'].plot()

# %%
data.YouTube.value_counts()
# Out:
# True     21
# False    15
# Name: YouTube, dtype: int64

# %%
data.Facebook.value_counts()
# Out:
# True     20
# False    16
# Name: Facebook, dtype: int64

# %%
data.Pinterest.value_counts()
# Out:
# False    19
# True     17
# Name: Pinterest, dtype: int64

# %%
data['Total']=data.select_dtypes(include=['bool']).sum(axis=1)

# %%
data
# Out:
#     period  YouTube  Facebook  Pinterest  time_spent  Total
# 0        1     True     False      False          14      1
# 1        2    False     False       True           0      1
# 2        3    False      True       True           3      2
# 3        4     True      True       True           4      3
# 4        5    False     False      False           2      0
# 5        6     True     False      False           2      1
# 6        7     True     False       True           8      2
# 7        8     True     False       True          15      2
# 8        9     True      True      False           1      2
# 9       10     True     False       True          12      2
# 10      11     True      True      False           9      2
# 11      12     True     False       True           9      2
# 12      13    False     False       True          13      1
# 13      14    False      True      False          12      1
# 14      15    False      True      False           1      1
# ...

# %%
plt.xlabel("Period")
plt.ylabel("Total SM Sites Used")
data['Total'].plot()

# %%
ax = plt.gca()

plt.xlabel("Period")
plt.ylabel("SM Sites Used & Time Spent")
data.plot(kind='line',x='period',y='time_spent',ax=ax)
data.plot(kind='line',x='period',y='Total', color='red', ax=ax)

plt.show()

# %%
high_usage = data[data['time_spent']>13]
high_usage
# Out:
#     period  YouTube  Facebook  Pinterest  time_spent  Total
# 0        1     True     False      False          14      1
# 7        8     True     False       True          15      2
# 19      20    False      True       True          14      2
# 21      22     True      True       True          15      3
