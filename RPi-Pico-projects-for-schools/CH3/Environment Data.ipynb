# %%
import pandas as pd

# %%
data= pd.read_csv("environment.csv",names=["Temp","Pressure","Humidity","Air Quality"])
data.head()
# Out:
#        Temp  Pressure  Humidity  Air Quality
# 0  19.51074  100787.1  61.80923   410444.600
# 1  19.53587  100785.9  61.80641    10254.170
# 2  19.53084  100787.7  61.74796     9232.594
# 3  19.53838  100786.3  61.70413    10364.830
# 4  19.55095  100793.8  61.66745    11742.580

# %% [markdown]
# 412 rows at roughly 1 row/second (ignoring the alarm) is just under 7 minutes.

# %%
412/60
# Out:
# 6.866666666666666

# %%
airQuality = data['Air Quality']
airQuality
# Out:
# 0      410444.600
# 1       10254.170
# 2        9232.594
# 3       10364.830
# 4       11742.580
#           ...
# 407     78621.090
# 408     78767.350
# 409     78621.090
# 410     78621.090
# 411     78402.740
# Name: Air Quality, Length: 412, dtype: float64

# %%
data.describe()
# Out:
#              Temp       Pressure    Humidity    Air Quality
# count  412.000000     412.000000  412.000000     412.000000
# mean    19.635302  100783.298058   60.731621   68976.966369
# std      0.083940       3.484920    0.373650   23142.179758
# min     19.483090  100774.600000   60.182090    9232.594000
# 25%     19.562893  100780.900000   60.448785   66977.882500
# 50%     19.632645  100783.300000   60.710455   75738.270000
# 75%     19.716850  100785.700000   60.838895   77826.330000
# max     19.769630  100795.000000   61.809230  410444.600000

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
airQuality.plot()

# %%
data = data.iloc[1:]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 1 to 411
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temp         411 non-null    float64
#  1   Pressure     411 non-null    float64
#  2   Humidity     411 non-null    float64
#  3   Air Quality  411 non-null    float64
# dtypes: float64(4)
# memory usage: 13.0 KB

# %%
airQuality = data['Air Quality']
airQuality.plot()

# %%
data = data.iloc[99:]
data.info()

airQuality = data['Air Quality']
airQuality.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 100 to 411
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temp         312 non-null    float64
#  1   Pressure     312 non-null    float64
#  2   Humidity     312 non-null    float64
#  3   Air Quality  312 non-null    float64
# dtypes: float64(4)
# memory usage: 9.9 KB

# %%
temp = data['Temp']
temp.plot()

# %%
humidity = data['Humidity']
humidity.plot()

# %%
pressure = data['Pressure']
pressure.plot()
